# %% [markdown]
# # 🌿 Plant Stress Detection - Colab Training
#
# Welcome! This notebook will setup the project, install dependencies, and run your experiments using Google Colab's fast GPUs.
#
# **Instructions:**
# 1. Go to **Runtime > Change runtime type** and select **T4 GPU** (or better).
# 2. Click **Run All** (Ctrl+F9) to start training.

# %%
# 1. Clone the repository
# !git clone https://github.com/Dany-John-C/PlantStressDetection.git
# %cd PlantStressDetection

# 2. Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 📂 Load Dataset from Google Drive
#
# Because datasets are large, they aren't stored on GitHub. You need to upload your dataset to Google Drive in order to train.
#
# **Steps:**
# 1. On your PC, zip your `dataset` folder so it becomes `dataset.zip`.
# 2. Upload `dataset.zip` to the main folder of your Google Drive.
# 3. Run the cell below to connect Google Drive and copy the dataset.

# %%
# 3. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 4. Unzip the dataset into the project folder
# !unzip -q /content/drive/MyDrive/dataset.zip -d /content/PlantStressDetection/
print("✅ Dataset successfully loaded from Google Drive!")

# %%
# 5. Run all experiments!
# !python run_experiments.py

# %% [markdown]
# ## ✅ Download Results
#
# Once the training above is fully complete, run the cell below to zip and download your `results` and `models` folders so you can use them locally in your dashboard.

# %%
# 6. Zip results and models
# !zip -r results_and_models.zip results/ models/

# 7. Trigger download to your local machine
from google.colab import files
files.download('results_and_models.zip')
